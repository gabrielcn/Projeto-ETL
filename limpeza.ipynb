# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True) #sep - seprador, sep=";" parse_dates (atributo usado para ele entender qual coluna vai ser transformada ou interpretada do tipo data). dayfirst=True define que o dia vem primeiro, ficnado no seguinte formato d/m/a.
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# ...

# %%
df.loc[1, 'ocorrencia_cidade'] # loc = localiza, a linha 1 e a coluna 'ocorrencia_cidade'
# Out:
# 'GUARULHOS'

# %%
df.loc[3]
# Out:
# codigo_ocorrencia                         45401
# codigo_ocorrencia2                        45401
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade                 SÃO SEBASTIÃO
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       ****
# ocorrencia_dia              2012-01-06 00:00:00
# ocorrencia_hora                        17:00:00
# total_recomendacoes                           0
# Name: 3, dtype: object

# %%
df.loc[1:3] # Localiza da linha 1 ate a 3.
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0

# %%
df.loc[[1,40]] # Localiza a linha 1 e alinha 40
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1               45331               45331                 ACIDENTE
# 40              45415               45415                 ACIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1          GUARULHOS            SP                 SBGR     2012-01-06
# 40    RIO DE JANEIRO            RJ                 ****     2012-01-30
#
#    ocorrencia_hora  total_recomendacoes
# 1         13:44:00                    3
# 40        13:55:00                    0

# %%
df.loc[:,'ocorrencia_cidade'] # Todos as linhas de uma coluna específica
# Out:
# 0        PORTO ALEGRE
# 1           GUARULHOS
# 2              VIAMÃO
# 3       SÃO SEBASTIÃO
# 4            SÃO SEPÉ
#             ...
# 5162            JATAÍ
# 5163          MARACAÍ
# 5164    NOVO HAMBURGO
# 5165         CURITIBA
# 5166        PETROLINA
# Name: ocorrencia_cidade, Length: 5167, dtype: object

# %%
df.codigo_ocorrencia.is_unique # Verifica se a coluna tem valores únicos em cada linha
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True) # Define a coluna 'codigo_ocorrencia' como index do dataframe, inplace=True aplica quando chamar o df

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# 45331                     GUARULHOS            SP                 SBGR
# 45333                        VIAMÃO            RS                 ****
# 45401                 SÃO SEBASTIÃO            SP                 ****
# 45407                      SÃO SEPÉ            RS                 ****
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# ...

# %%
df
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
# ...                               ...                      ...
# 80458                           80458                 ACIDENTE
# 80452                           80452                 ACIDENTE
# 80457                           80457          INCIDENTE GRAVE
# 80460                           80460                INCIDENTE
# 80467                           80467                INCIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# ...

# %%
df.loc[52242]
# Out:
# codigo_ocorrencia2                        52242
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                  PORTO ALEGRE
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       SBPA
# ocorrencia_dia              2012-01-05 00:00:00
# ocorrencia_hora                        20:27:00
# total_recomendacoes                           0
# Name: 52242, dtype: object

# %%
df.reset_index(drop=True, inplace=True) # Resetar o indice, inplace=True (no df local tb)

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                 ACIDENTE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                 ACIDENTE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...

# %%
df.loc[2, 'ocorrencia_aerodromo'] = ''  # alterando valores

# %%
df.head(2)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
#
#    total_recomendacoes
# 0                    0
# 1                    3

# %%
df.loc[:, 'total_recomendacoes'] = 10 # Altera todos os valores de uma coluna para '10'

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf # Backup de uma coluna

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                 ACIDENTE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                 ACIDENTE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE' # Onde o uf for SP, altere na coluna 'ocorrencia_classificacao' com a palavra 'GRAVE'

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                    GRAVE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                    GRAVE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                    GRAVE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP'] # filtro
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao  ocorrencia_cidade  \
# 1                  45331                    GRAVE          GUARULHOS
# 3                  45401                    GRAVE      SÃO SEBASTIÃO
# 5                  52243                    GRAVE            UBATUBA
# 6                  50713                    GRAVE           CAMPINAS
# 13                 45408                    GRAVE           ELDORADO
# ...                  ...                      ...                ...
# 5148               80441                    GRAVE  BRAGANÇA PAULISTA
# 5157               80453                    GRAVE           CAMPINAS
# 5158               80454                    GRAVE          ARAÇATUBA
# 5161               80456                    GRAVE          SÃO PAULO
# 5163               80452                    GRAVE            MARACAÍ
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                    GRAVE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                    GRAVE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                    GRAVE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                    GRAVE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                    GRAVE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                          2012-01-06        13:00:00
# 3            SP                 ****     2012-01-06        17:00:00
# 4            RS                 ****     2012-01-06        16:30:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                   10                RS
# 1                   10                SP
# ...

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA # Substituindo valores '****' na coluna ocorrencia_aerodromo pelo o atributo de valores não informados no pandas (pd.NA) na coluna ocorrencia_aerodromo

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                    GRAVE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                    GRAVE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                    GRAVE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...

# %% [markdown]
# ocorrencia_uf
# **
#
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
#
# ocorrencia_hora
# NULL

# %%
df.replace(['**', '###!', '####', '****', '*****', 'NULL'], pd.NA, inplace=True) # Procura todos esses valores da lista e substitui por pd.NA

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                    GRAVE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                    GRAVE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                    GRAVE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...

# %%
df.tail()
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                    GRAVE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 5162            GO                 <NA>     2021-12-30        20:30:00
# 5163            SP                 <NA>     2021-12-31        09:30:00
# 5164            RS                 SSNH     2021-12-31        11:59:00
# 5165            PR                 SBBI     2021-12-31        15:12:00
# 5166            PE                 SBPL     2021-12-31        20:30:00
#
#       total_recomendacoes ocorrencia_uf_bkp
# 5162                   10                GO
# ...

# %%
df.isna().sum() # Somar quantos dados não informados por coluna
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        1904
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# ocorrencia_uf_bkp              0
# dtype: int64

# %%
df.isnull() # isnull e isna é a mesma coisa
# Out:
#       codigo_ocorrencia2  ocorrencia_classificacao  ocorrencia_cidade  \
# 0                  False                     False              False
# 1                  False                     False              False
# 2                  False                     False              False
# 3                  False                     False              False
# 4                  False                     False              False
# ...                  ...                       ...                ...
# 5162               False                     False              False
# 5163               False                     False              False
# 5164               False                     False              False
# 5165               False                     False              False
# 5166               False                     False              False
#
#       ocorrencia_uf  ocorrencia_aerodromo  ocorrencia_dia  ocorrencia_hora  \
# ...

# %%
df.fillna(0) # Atribui um valor no dado não informado (mudou só em twmpo de visualização)
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                    GRAVE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                    GRAVE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                    GRAVE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...

# %%
df.fillna(10, inplace=True) # muda no df local

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# ocorrencia_uf_bkp           0
# dtype: int64

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                    GRAVE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                    GRAVE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                          2012-01-06        13:00:00
# 3            SP                   10     2012-01-06        17:00:00
# 4            RS                   10     2012-01-06        16:30:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                   10                RS
# 1                   10                SP
# ...

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        1904
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes         5167
# ocorrencia_uf_bkp              0
# dtype: int64

# %%
df.fillna(value={'ocorrencia_hora': 'NULL'}, inplace=True) # Altera somente na coluna ocorrencia_hora os valores que estiverem nulos

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        1904
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes         5167
# ocorrencia_uf_bkp              0
# dtype: int64

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.head()
# Out:
#   codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 0              52242                INCIDENTE      PORTO ALEGRE            RS
# 1              45331                    GRAVE         GUARULHOS            SP
# 2              45333                 ACIDENTE            VIAMÃO            RS
# 3              45401                    GRAVE     SÃO SEBASTIÃO            SP
# 4              45407                 ACIDENTE          SÃO SEPÉ            RS
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora total_recomendacoes  \
# 0                 SBPA     2012-01-05        20:27:00                <NA>
# 1                 SBGR     2012-01-06        13:44:00                <NA>
# 2                          2012-01-06        13:00:00                <NA>
# 3                 <NA>     2012-01-06        17:00:00                <NA>
# 4                 <NA>     2012-01-06        16:30:00                <NA>
#
#   ocorrencia_uf_bkp total_recomendacoes_bkp
# ...

# %%
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True) # Excluir uma coluna, axis = 1 é o eixo de coluna, axis = 0 é o eixo de linha

# %%
df.head()
# Out:
#   codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 0              52242                INCIDENTE      PORTO ALEGRE            RS
# 1              45331                    GRAVE         GUARULHOS            SP
# 2              45333                 ACIDENTE            VIAMÃO            RS
# 3              45401                    GRAVE     SÃO SEBASTIÃO            SP
# 4              45407                 ACIDENTE          SÃO SEPÉ            RS
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora total_recomendacoes  \
# 0                 SBPA     2012-01-05        20:27:00                <NA>
# 1                 SBGR     2012-01-06        13:44:00                <NA>
# 2                          2012-01-06        13:00:00                <NA>
# 3                 <NA>     2012-01-06        17:00:00                <NA>
# 4                 <NA>     2012-01-06        16:30:00                <NA>
#
#   ocorrencia_uf_bkp
# 0                RS
# ...

# %%
df.dropna() # Exclui todos os valores não informados
# Out:
# Empty DataFrame
# Columns: [codigo_ocorrencia2, ocorrencia_classificacao, ocorrencia_cidade, ocorrencia_uf, ocorrencia_aerodromo, ocorrencia_dia, ocorrencia_hora, total_recomendacoes, ocorrencia_uf_bkp]
# Index: []

# %%
df
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                 52242                INCIDENTE      PORTO ALEGRE
# 1                 45331                    GRAVE         GUARULHOS
# 2                 45333                 ACIDENTE            VIAMÃO
# 3                 45401                    GRAVE     SÃO SEBASTIÃO
# 4                 45407                 ACIDENTE          SÃO SEPÉ
# ...                 ...                      ...               ...
# 5162              80458                 ACIDENTE             JATAÍ
# 5163              80452                    GRAVE           MARACAÍ
# 5164              80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165              80460                INCIDENTE          CURITIBA
# 5166              80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...

# %%
df.dropna(subset=['ocorrencia_aerodromo']) # Exclui as linhas c/ valores NA na coluna acorrencia_aerodromo
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                 52242                INCIDENTE      PORTO ALEGRE
# 1                 45331                    GRAVE         GUARULHOS
# 2                 45333                 ACIDENTE            VIAMÃO
# 6                 50713                    GRAVE          CAMPINAS
# 7                 45334                INCIDENTE             BELÉM
# ...                 ...                      ...               ...
# 5160              80451                INCIDENTE            MANAUS
# 5161              80456                    GRAVE         SÃO PAULO
# 5164              80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165              80460                INCIDENTE          CURITIBA
# 5166              80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...

# %%
df.drop_duplicates(inplace=True) # Exclui linhas duplicadas

# %%
df
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                 52242                INCIDENTE      PORTO ALEGRE
# 1                 45331                    GRAVE         GUARULHOS
# 2                 45333                 ACIDENTE            VIAMÃO
# 3                 45401                    GRAVE     SÃO SEBASTIÃO
# 4                 45407                 ACIDENTE          SÃO SEPÉ
# ...                 ...                      ...               ...
# 5162              80458                 ACIDENTE             JATAÍ
# 5163              80452                    GRAVE           MARACAÍ
# 5164              80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165              80460                INCIDENTE          CURITIBA
# 5166              80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...
